# %%
# Initialize Otter
import otter
grader = otter.Notebook("template.ipynb")

# %% [markdown]
# ![](img/logo.png)

# %% [markdown]
# # Assignment template

# %% [markdown]
# ## Exercise 1: [Insert title here]
#
# {rubric: accuracy = 5}
#
# [Insert description here, e.g. write a function to sum two numbers]

# %%
def sum(a, b):
    ...

# %% [markdown]
# Run the test below to see if you have done it correctly
# > Note: There might be hidden tests that are not shown here

# %%
grader.check("ex1")

# %% [markdown]
# ## Exercise 2: [Insert title here]
#
# {rubric: accuracy = 5}
#
# [Insert description here, e.g. import iris.csv as a pandas dataframe called `df`]

# %%
import pandas as pd
df = ...

# %% [markdown]
# Run the test below to see if you have done it correctly
# > Note: There might be hidden tests that are not shown here

# %%
grader.check("ex2")

# %% [markdown]
# Run this code cell below to plot your data

# %%
import matplotlib.pyplot as plt
# plot scatter plot
plt.scatter(df["sepal.length"], df["sepal.width"])

# %% [markdown]
# ## Exercise 3 (MANUAL QUESTION): [Insert title here]
#
# {rubric: reasoning = 5}
#
# [Insert description here, e.g. import iris.csv as a pandas dataframe called `df`]

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question:** What do you notice about the scatter plot?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Submission instructions
#
# {rubric: mechanics = 5}
#
# - Make sure the notebook can run from top to bottom without any error. Restart the kernel and run all cells.
# - Submit to Gradescope
